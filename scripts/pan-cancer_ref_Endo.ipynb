# %%
import numpy as np
import pandas as pd
import scanpy as sc 
import anndata as ad
import diopy

# %%
adata=sc.read_h5ad('/bigdata/zlin//PanCancer_ICI/data/pan-cancer_Endo/NSR.panE.exprs.all.h5ad.gz')
# Out:
# /bigdata/zlin/miniconda3/envs/scrna/lib/python3.9/site-packages/anndata/_core/anndata.py:183: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
adata.obs=pd.read_csv('/bigdata/zlin//PanCancer_ICI/data/pan-cancer_Endo/NSR.panE.obs.meta.csv', index_col=0)
# Out:
# /bigdata/zlin/miniconda3/envs/scrna/lib/python3.9/site-packages/anndata/_core/anndata.py:859: UserWarning:
# AnnData expects .obs.index to contain strings, but got values like:
#     [0, 1, 2, 3, 4]
#
#     Inferred to be: integer
#
#   value_idx = self._prep_dim_index(value.index, attr)

# %%
adata.obs
# Out:
#         cellID        sampleID patientID tissue cancerType platform  \
# 0            0    D01_P1_Tumor    D01_P1      T       cSCC    10X_3
# 1            1    D01_P1_Tumor    D01_P1      T       cSCC    10X_3
# 2            2    D01_P1_Tumor    D01_P1      T       cSCC    10X_3
# 3            3    D01_P1_Tumor    D01_P1      T       cSCC    10X_3
# 4            4    D01_P1_Tumor    D01_P1      T       cSCC    10X_3
# ...        ...             ...       ...    ...        ...      ...
# 149849  149849  D46_GSM5075670  D46_p013      T        CRC    10X_3
# 149850  149850  D46_GSM5075670  D46_p013      T        CRC    10X_3
# 149851  149851  D46_GSM5075670  D46_p013      T        CRC    10X_3
# 149852  149852  D46_GSM5075670  D46_p013      T        CRC    10X_3
# 149853  149853  D46_GSM5075670  D46_p013      T        CRC    10X_3
#
#        cellType.major          cellType.sub        Dataset
# 0               veins        E06.veins.SELE  D01_GSE144236
# ...

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 149854 × 19818
#     obs: 'cellID', 'sampleID', 'patientID', 'tissue', 'cancerType', 'platform', 'cellType.major', 'cellType.sub', 'Dataset'

# %%
# in Python
diopy.output.write_h5(adata,file = '/bigdata/zlin//PanCancer_ICI/data/pan-cancer_Endo/NSRpanE.h5')
